# %%
# %ls
# Out:
# datasets/  README.md  requirements.txt  Untitled.ipynb

# %%
import math
import pandas as pd

# %%
type(None)
# Out:
# NoneType

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type("math.pi")
# Out:
# str

# %%
type(0)
# Out:
# int

# %% [markdown]
# # lists

# %%
aList = [2, 3, 4, 5, None, 'aName', False, math.pi, 'math.pi', 4.5]

# %%
aList
# Out:
# [2, 3, 4, 5, None, 'aName', False, 3.141592653589793, 'math.pi', 4.5]

# %%
print(*aList)
# Out:
# 2 3 4 5 None aName False 3.141592653589793 math.pi 4.5

# %%
for i in aList:
    print(i, '\t', type(i))
# Out:
# 2 	 <class 'int'>
# 3 	 <class 'int'>
# 4 	 <class 'int'>
# 5 	 <class 'int'>
# None 	 <class 'NoneType'>
# aName 	 <class 'str'>
# False 	 <class 'bool'>
# 3.141592653589793 	 <class 'float'>
# math.pi 	 <class 'str'>
# 4.5 	 <class 'float'>

# %%
numbers = [1, 5, 8, 10]

# %%
numbers
# Out:
# [1, 5, 8, 10]

# %%
type(sum(numbers))
# Out:
# int

# %%
# 2^2
2**2
# Out:
# 4

# %%
# 6*10^(-1)
6*10**(-1)
# Out:
# 0.6000000000000001

# %% [markdown]
# # Variable Types
# #### 1. Numerical
# #### 2. Categorical or Qualitative

# %%
'2012'*2
# Out:
# '20122012'

# %%
print('*'*115)
# Out:
# *******************************************************************************************************************

# %%
x = 5
y = 7
if x < y:
    print(' {} is less than {}'.format(x,y))
else:
    print(' {} is greater than {}'.format(x,y))
# Out:
#  5 is less than 7

# %%
x = 5
y = 7
if x < y:
    print(x,'is less than',y)
else: 
    print(y, 'is greater than', x)
# Out:
# 5 is less than 7

# %%
boolList = [True, 6>10, 1==3, None is None]
for i in boolList:
    print(i, '\t', type(i))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# # Sorting

# %%
aList = ['d', 'a', 'b', 'e', 'c']
print(*aList)
# Out:
# d a b e c

# %%
aList.sort()
print(aList)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
# listName[startingPoint : EndingPoint(without)]
aList[:5]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
aList[-3:]
# Out:
# ['c', 'd', 'e']

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
path = 'datasets/Cartwheeldata.csv'
df = pd.read_csv(path)
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.tail()
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
x = df.columns
x = x.tolist()
x.sort()
print(*x, sep = ', ')
# Out:
# Age, CWDistance, Complete, CompleteGroup, Gender, GenderGroup, Glasses, GlassesGroup, Height, ID, Score, Wingspan

# %%
type(x)
# Out:
# list

# %% [markdown]
# # Loc and iLoc
#
# ## Loc
#     df.loc[rowStart:rowEnd , ColumnStart:ColumnEnd]  #  ID_Names
#
# ## iLoc
#     df.iloc[rowStart:rowEnd , ColumnStart:ColumnEnd]  #  ID_Indices

# %%
df.loc[:,'CWDistance'].head(2)
# Out:
# 0    79
# 1    70
# Name: CWDistance, dtype: int64

# %%
df.iloc[:, 8].head(2)
# Out:
# 0    79
# 1    70
# Name: CWDistance, dtype: int64

# %%
df.iloc[:, -4:-3]
# Out:
#     CWDistance
# 0           79
# 1           70
# 2           85
# 3           87
# 4           72
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96
# 11          79
# 12          92
# 13          66
# 14          72
# 15         115
# 16          90
# 17          74
# 18          64
# 19          85
# 20          66
# 21         101
# 22          82
# 23          63
# 24          67

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.loc[:2, ['GenderGroup', 'Glasses', 'GlassesGroup', 'Height']]
# Out:
#    GenderGroup Glasses  GlassesGroup  Height
# 0            1       Y             1    62.0
# 1            1       Y             1    62.0
# 2            1       Y             1    66.0
